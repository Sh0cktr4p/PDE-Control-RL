# %% [markdown]
# # Controlling Burgers' Equation with Reinforcement Learning
# This notebook will demonstrate how reinforcement learning can be used to control Burgers' equation, a nonlinear PDE. The approach uses the reinforcement learning framework [stable_baselines3](https://github.com/DLR-RM/stable-baselines3) and the differentiable PDE solver [Φ<sub>Flow</sub>](https://github.com/tum-pbs/PhiFlow). As a reinforcement learning algorithm, [PPO](https://arxiv.org/abs/1707.06347v2) was selected.

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('../src'); sys.path.append('../PDE-Control/PhiFlow'); sys.path.append('../PDE-Control/src')
from phi.flow import *
import matplotlib.pyplot as plt
import burgers_plots as bplt
from experiment import BurgersTraining
# Out:
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.

# %% [markdown]
# ## Reinforcement Learning Initialization

# %%
domain = Domain([32], box=box[0:1]) # 1d grid resolution and physical size
viscosity = 0.003 # viscosity constant for Burgers' equation
step_count = 32 # length of each trajectory
dt = 0.03 # time step size
diffusion_substeps = 1 # how many diffusion steps to perform at each solver step

n_envs = 10 # On how many environments to train in parallel, load balancing
final_reward_factor = step_count # How hard to punish the agent for not reaching the goal if that is the case
steps_per_rollout = step_count * 10 # How many steps to collect per environment between agent updates
training_timesteps = steps_per_rollout * 1000 # How long the actual training should be
n_epochs = 10 # How many epochs to perform during agent update
learning_rate = 1e-4 # Learning rate for agent updates
batch_size = 128 # Batch size for agent updates
test_path = 'forced-burgers-clash' # Path of the used test set for comparison to cfe method
test_range = range(100) # Test samples inside the dataset

# %% [markdown]
# To start training, we create a trainer object, which manages the environment and the agent internally. Additionally, a directory for storing models, logs, and hyperparameters is created. This way, training can be continued at any later point using the same configuration. If the model folder specified in `exp_name` already exists, the agent within is loaded. Otherwise, a new agent is created

# %%
trainer = BurgersTraining(
    exp_name='../networks/rl-models/ControlBurgersBench',
    domain=domain,
    viscosity=viscosity,
    step_count=step_count,
    dt=dt,
    diffusion_substeps=diffusion_substeps,
    n_envs=n_envs,
    final_reward_factor=final_reward_factor,
    steps_per_rollout=steps_per_rollout,
    n_epochs=n_epochs,
    learning_rate=learning_rate,
    batch_size=batch_size,
    test_path=test_path,
    test_range=range(100),
)
# Out:
# Using new running mean for reward
# Creating new agent...
# Using given reward rms
# Using cuda device

# %% [markdown]
# Now we are set up to start training the agent. The next line will take quite some time to execute, so grab a coffee or take your dog for a walk or so.
#
# `n_rollouts` denotes the length of the training
#
# `save_freq` specifies the number of epochs after which the stored model is overwritten

# %%
trainer.train(n_rollouts=1000, save_freq=50)
# Out:
# Logging to ../networks/rl-models/ControlBurgersBench/tensorboard-log/PPO_1
# Storing agent and hyperparameters to disk...
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/torch/nn/functional.py:2506: UserWarning:
#
# Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# Forces on test set: 34499.577050
# -----------------------------------
# | forces             | 1143.5386  |
# | rew_unnormalized   | -262437.3  |
# | rollout/           |            |
# |    ep_len_mean     | 32.0       |
# |    ep_rew_mean     | -0.5929396 |
# | test set forces    | 3.45e+04   |
# | time/              |            |
# |    fps             | 664        |
# |    iterations      | 1          |
# |    time_elapsed    | 4          |
# |    total_timesteps | 3200       |
# -----------------------------------
# Forces on test set: 35935.269890
# -----------------------------------------
# | forces                  | 1124.006    |
# | rew_unnormalized        | -245304.72  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.13344853  |
# | test set forces         | 3.59e+04    |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 2           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.010111482 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | -4.85e+06   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.82        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00951    |
# |    std                  | 1           |
# |    value_loss           | 7.35        |
# -----------------------------------------
# Forces on test set: 37024.744675
# -----------------------------------------
# | forces                  | 1124.8269   |
# | rew_unnormalized        | -235055.48  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.20057459  |
# | test set forces         | 3.7e+04     |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 3           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 9600        |
# | train/                  |             |
# |    approx_kl            | 0.009373227 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | -8.08e+03   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.42        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 1           |
# |    value_loss           | 6.4         |
# -----------------------------------------
# Forces on test set: 37543.575035
# ------------------------------------------
# | forces                  | 1132.7256    |
# | rew_unnormalized        | -258033.6    |
# | rollout/                |              |
# |    ep_len_mean          | 32.0         |
# |    ep_rew_mean          | -0.1368856   |
# | test set forces         | 3.75e+04     |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 4            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0073498427 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.4        |
# |    explained_variance   | -25.8        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.2          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00596     |
# |    std                  | 1            |
# |    value_loss           | 2.9          |
# ------------------------------------------
# Forces on test set: 37708.370590
# -----------------------------------------
# | forces                  | 1105.0372   |
# | rew_unnormalized        | -213492.52  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.4950322   |
# | test set forces         | 3.77e+04    |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 5           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.013262036 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | -1.2        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.1         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00953    |
# |    std                  | 1           |
# |    value_loss           | 2.88        |
# -----------------------------------------
# Forces on test set: 37824.071587
# -----------------------------------------
# | forces                  | 1150.8021   |
# | rew_unnormalized        | -274759.88  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | -0.4493769  |
# | test set forces         | 3.78e+04    |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 6           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.009342036 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.644       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00789    |
# |    std                  | 1           |
# |    value_loss           | 1.31        |
# -----------------------------------------
# Forces on test set: 38106.547134
# -----------------------------------------
# | forces                  | 1138.7535   |
# | rew_unnormalized        | -262921.47  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | -0.2678847  |
# | test set forces         | 3.81e+04    |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 7           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 22400       |
# | train/                  |             |
# |    approx_kl            | 0.008597434 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.334       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00835    |
# |    std                  | 1           |
# |    value_loss           | 0.952       |
# -----------------------------------------
# Forces on test set: 37653.692635
# ------------------------------------------
# | forces                  | 1184.4374    |
# | rew_unnormalized        | -312650.62   |
# | rollout/                |              |
# |    ep_len_mean          | 32.0         |
# |    ep_rew_mean          | -0.91361845  |
# | test set forces         | 3.77e+04     |
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 8            |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0037284566 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.4        |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.54         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00886     |
# |    std                  | 1            |
# |    value_loss           | 1.01         |
# ------------------------------------------
# Forces on test set: 37775.603287
# -----------------------------------------
# | forces                  | 1127.5168   |
# | rew_unnormalized        | -247447.28  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.16077591  |
# | test set forces         | 3.78e+04    |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 9           |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 28800       |
# | train/                  |             |
# |    approx_kl            | 0.003508445 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.413       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00603    |
# |    std                  | 1           |
# |    value_loss           | 0.635       |
# -----------------------------------------
# Forces on test set: 37768.909721
# -----------------------------------------
# | forces                  | 1143.9934   |
# | rew_unnormalized        | -269292.6   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | -0.19531393 |
# | test set forces         | 3.78e+04    |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 10          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.006911783 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.123       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00897    |
# |    std                  | 1           |
# |    value_loss           | 0.498       |
# -----------------------------------------
# Forces on test set: 37472.989105
# ------------------------------------------
# | forces                  | 1132.7501    |
# | rew_unnormalized        | -258016.56   |
# | rollout/                |              |
# |    ep_len_mean          | 32.0         |
# |    ep_rew_mean          | 0.0031076432 |
# | test set forces         | 3.75e+04     |
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 11           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 35200        |
# | train/                  |              |
# |    approx_kl            | 0.0035903596 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.4        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.144        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 1            |
# |    value_loss           | 0.38         |
# ------------------------------------------
# Forces on test set: 37011.672379
# -----------------------------------------
# | forces                  | 1116.0458   |
# | rew_unnormalized        | -233794.5   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.35488087  |
# | test set forces         | 3.7e+04     |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 12          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 38400       |
# | train/                  |             |
# |    approx_kl            | 0.005815636 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.114       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 1           |
# |    value_loss           | 0.325       |
# -----------------------------------------
# Forces on test set: 36757.867371
# ------------------------------------------
# | forces                  | 1143.5074    |
# | rew_unnormalized        | -261159.78   |
# | rollout/                |              |
# |    ep_len_mean          | 32.0         |
# |    ep_rew_mean          | -0.062348157 |
# | test set forces         | 3.68e+04     |
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 13           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 41600        |
# | train/                  |              |
# |    approx_kl            | 0.0071282173 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.4        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.16         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0103      |
# |    std                  | 1            |
# |    value_loss           | 0.34         |
# ------------------------------------------
# Forces on test set: 36752.745567
# -----------------------------------------
# | forces                  | 1117.4675   |
# | rew_unnormalized        | -238254.8   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.26887485  |
# | test set forces         | 3.68e+04    |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 14          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 44800       |
# | train/                  |             |
# |    approx_kl            | 0.007005316 |
# |    clip_fraction        | 0.0511      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.106       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 1           |
# |    value_loss           | 0.204       |
# -----------------------------------------
# Forces on test set: 37283.177605
# ------------------------------------------
# | forces                  | 1099.3871    |
# | rew_unnormalized        | -211648.38   |
# | rollout/                |              |
# |    ep_len_mean          | 32.0         |
# |    ep_rew_mean          | 0.65364337   |
# | test set forces         | 3.73e+04     |
# | time/                   |              |
# |    fps                  | 247          |
# |    iterations           | 15           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 48000        |
# | train/                  |              |
# |    approx_kl            | 0.0070038154 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.4        |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.102        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 1            |
# |    value_loss           | 0.24         |
# ------------------------------------------
# Forces on test set: 37448.255768
# -----------------------------------------
# | forces                  | 1124.6333   |
# | rew_unnormalized        | -235973.05  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.24260071  |
# | test set forces         | 3.74e+04    |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 16          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004430337 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0864      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 1           |
# |    value_loss           | 0.201       |
# -----------------------------------------
# Forces on test set: 37522.926712
# ----------------------------------------
# | forces                  | 1136.8605  |
# | rew_unnormalized        | -247083.08 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 0.06278217 |
# | test set forces         | 3.75e+04   |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 17         |
# |    time_elapsed         | 224        |
# |    total_timesteps      | 54400      |
# | train/                  |            |
# |    approx_kl            | 0.01045771 |
# |    clip_fraction        | 0.0952     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -45.4      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0714     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0167    |
# |    std                  | 1          |
# |    value_loss           | 0.195      |
# ----------------------------------------
# Forces on test set: 38034.041977
# ------------------------------------------
# | forces                  | 1143.6226    |
# | rew_unnormalized        | -258097.95   |
# | rollout/                |              |
# |    ep_len_mean          | 32.0         |
# |    ep_rew_mean          | -0.10245581  |
# | test set forces         | 3.8e+04      |
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 18           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 57600        |
# | train/                  |              |
# |    approx_kl            | 0.0048261476 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.4        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0861       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 1            |
# |    value_loss           | 0.237        |
# ------------------------------------------
# Forces on test set: 38124.677902
# ------------------------------------------
# | forces                  | 1097.6388    |
# | rew_unnormalized        | -207116.66   |
# | rollout/                |              |
# |    ep_len_mean          | 32.0         |
# |    ep_rew_mean          | 0.69071275   |
# | test set forces         | 3.81e+04     |
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 19           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 60800        |
# | train/                  |              |
# |    approx_kl            | 0.0050637317 |
# |    clip_fraction        | 0.0725       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.4        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.082        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0129      |
# |    std                  | 1            |
# |    value_loss           | 0.215        |
# ------------------------------------------
# Forces on test set: 38583.571198
# -----------------------------------------
# | forces                  | 1087.5135   |
# | rew_unnormalized        | -194920.22  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.8466505   |
# | test set forces         | 3.86e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 20          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 64000       |
# | train/                  |             |
# |    approx_kl            | 0.011777011 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0605      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 1           |
# |    value_loss           | 0.188       |
# -----------------------------------------
# Forces on test set: 38857.090912
# -----------------------------------------
# | forces                  | 1083.8105   |
# | rew_unnormalized        | -193357.12  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.8364024   |
# | test set forces         | 3.89e+04    |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 21          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 67200       |
# | train/                  |             |
# |    approx_kl            | 0.008251564 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0827      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.999       |
# |    value_loss           | 0.182       |
# -----------------------------------------
# Forces on test set: 39244.139465
# -----------------------------------------
# | forces                  | 1094.9098   |
# | rew_unnormalized        | -208879.98  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.5579582   |
# | test set forces         | 3.92e+04    |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 22          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 70400       |
# | train/                  |             |
# |    approx_kl            | 0.007180655 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0343      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.999       |
# |    value_loss           | 0.16        |
# -----------------------------------------
# Forces on test set: 39681.125793
# -----------------------------------------
# | forces                  | 1109.6996   |
# | rew_unnormalized        | -205359.2   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.5899993   |
# | test set forces         | 3.97e+04    |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 23          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 73600       |
# | train/                  |             |
# |    approx_kl            | 0.013826677 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0929      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.999       |
# |    value_loss           | 0.16        |
# -----------------------------------------
# Forces on test set: 40428.232849
# ------------------------------------------
# | forces                  | 1075.4285    |
# | rew_unnormalized        | -168579.34   |
# | rollout/                |              |
# |    ep_len_mean          | 32.0         |
# |    ep_rew_mean          | 1.1783569    |
# | test set forces         | 4.04e+04     |
# | time/                   |              |
# |    fps                  | 232          |
# |    iterations           | 24           |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 76800        |
# | train/                  |              |
# |    approx_kl            | 0.0084847305 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.4        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0818       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.016       |
# |    std                  | 0.998        |
# |    value_loss           | 0.166        |
# ------------------------------------------
# Forces on test set: 40717.534088
# ----------------------------------------
# | forces                  | 1076.8336  |
# | rew_unnormalized        | -169720.08 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.117404   |
# | test set forces         | 4.07e+04   |
# | time/                   |            |
# |    fps                  | 233        |
# |    iterations           | 25         |
# |    time_elapsed         | 342        |
# |    total_timesteps      | 80000      |
# | train/                  |            |
# |    approx_kl            | 0.00866505 |
# |    clip_fraction        | 0.126      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -45.4      |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0497     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.016     |
# |    std                  | 0.999      |
# |    value_loss           | 0.132      |
# ----------------------------------------
# Forces on test set: 41008.844330
# -----------------------------------------
# | forces                  | 1069.7668   |
# | rew_unnormalized        | -154138.19  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3442922   |
# | test set forces         | 4.1e+04     |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 26          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 83200       |
# | train/                  |             |
# |    approx_kl            | 0.012759478 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0811      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.997       |
# |    value_loss           | 0.171       |
# -----------------------------------------
# Forces on test set: 41422.865112
# -----------------------------------------
# | forces                  | 1051.4697   |
# | rew_unnormalized        | -140604.84  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.5352063   |
# | test set forces         | 4.14e+04    |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 27          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 86400       |
# | train/                  |             |
# |    approx_kl            | 0.013084102 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0789      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.996       |
# |    value_loss           | 0.141       |
# -----------------------------------------
# Forces on test set: 42171.022705
# ------------------------------------------
# | forces                  | 1090.9088    |
# | rew_unnormalized        | -186192.16   |
# | rollout/                |              |
# |    ep_len_mean          | 32.0         |
# |    ep_rew_mean          | 0.7174134    |
# | test set forces         | 4.22e+04     |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 28           |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 89600        |
# | train/                  |              |
# |    approx_kl            | 0.0064416504 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.3        |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0561       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0154      |
# |    std                  | 0.997        |
# |    value_loss           | 0.151        |
# ------------------------------------------
# Forces on test set: 42368.041992
# ------------------------------------------
# | forces                  | 1083.39      |
# | rew_unnormalized        | -167548.0    |
# | rollout/                |              |
# |    ep_len_mean          | 32.0         |
# |    ep_rew_mean          | 1.014181     |
# | test set forces         | 4.24e+04     |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 29           |
# |    time_elapsed         | 392          |
# |    total_timesteps      | 92800        |
# | train/                  |              |
# |    approx_kl            | 0.0050842143 |
# |    clip_fraction        | 0.099        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.3        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0669       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0125      |
# |    std                  | 0.998        |
# |    value_loss           | 0.157        |
# ------------------------------------------
# Forces on test set: 43176.526550
# -----------------------------------------
# | forces                  | 1037.8071   |
# | rew_unnormalized        | -122334.02  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.7776068   |
# | test set forces         | 4.32e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 30          |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 96000       |
# | train/                  |             |
# |    approx_kl            | 0.011280397 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0483      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.998       |
# |    value_loss           | 0.151       |
# -----------------------------------------
# Forces on test set: 43693.061340
# -----------------------------------------
# | forces                  | 1033.252    |
# | rew_unnormalized        | -120088.95  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.777583    |
# | test set forces         | 4.37e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 31          |
# |    time_elapsed         | 417         |
# |    total_timesteps      | 99200       |
# | train/                  |             |
# |    approx_kl            | 0.011652326 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0542      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.998       |
# |    value_loss           | 0.112       |
# -----------------------------------------
# Forces on test set: 44500.204163
# ----------------------------------------
# | forces                  | 1054.5348  |
# | rew_unnormalized        | -133124.83 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.5083287  |
# | test set forces         | 4.45e+04   |
# | time/                   |            |
# |    fps                  | 238        |
# |    iterations           | 32         |
# |    time_elapsed         | 428        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01282673 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -45.3      |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00469   |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0156    |
# |    std                  | 0.997      |
# |    value_loss           | 0.108      |
# ----------------------------------------
# Forces on test set: 44892.029053
# -----------------------------------------
# | forces                  | 1034.3685   |
# | rew_unnormalized        | -112464.31  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.8428862   |
# | test set forces         | 4.49e+04    |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 33          |
# |    time_elapsed         | 440         |
# |    total_timesteps      | 105600      |
# | train/                  |             |
# |    approx_kl            | 0.012252769 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0451      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.996       |
# |    value_loss           | 0.114       |
# -----------------------------------------
# Forces on test set: 45455.907166
# -----------------------------------------
# | forces                  | 1030.1382   |
# | rew_unnormalized        | -105703.75  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.9346317   |
# | test set forces         | 4.55e+04    |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 34          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 108800      |
# | train/                  |             |
# |    approx_kl            | 0.012881973 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0619      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.996       |
# |    value_loss           | 0.13        |
# -----------------------------------------
# Forces on test set: 45843.669189
# ----------------------------------------
# | forces                  | 1060.8185  |
# | rew_unnormalized        | -119586.01 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.643074   |
# | test set forces         | 4.58e+04   |
# | time/                   |            |
# |    fps                  | 240        |
# |    iterations           | 35         |
# |    time_elapsed         | 465        |
# |    total_timesteps      | 112000     |
# | train/                  |            |
# |    approx_kl            | 0.01175921 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -45.3      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.033      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0126    |
# |    std                  | 0.996      |
# |    value_loss           | 0.116      |
# ----------------------------------------
# Forces on test set: 45996.432739
# -----------------------------------------
# | forces                  | 1034.8649   |
# | rew_unnormalized        | -103619.22  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.9074765   |
# | test set forces         | 4.6e+04     |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 36          |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 115200      |
# | train/                  |             |
# |    approx_kl            | 0.015527984 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0399      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.997       |
# |    value_loss           | 0.0919      |
# -----------------------------------------
# Forces on test set: 46035.476990
# -----------------------------------------
# | forces                  | 1047.8807   |
# | rew_unnormalized        | -107385.98  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.802368    |
# | test set forces         | 4.6e+04     |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 37          |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 118400      |
# | train/                  |             |
# |    approx_kl            | 0.009949379 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0262      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.997       |
# |    value_loss           | 0.0924      |
# -----------------------------------------
# Forces on test set: 46328.587830
# -----------------------------------------
# | forces                  | 1012.8283   |
# | rew_unnormalized        | -85974.25   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 2.177551    |
# | test set forces         | 4.63e+04    |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 38          |
# |    time_elapsed         | 502         |
# |    total_timesteps      | 121600      |
# | train/                  |             |
# |    approx_kl            | 0.007534553 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.042       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.996       |
# |    value_loss           | 0.104       |
# -----------------------------------------
# Forces on test set: 46452.984985
# -----------------------------------------
# | forces                  | 1008.4485   |
# | rew_unnormalized        | -81145.95   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 2.2365463   |
# | test set forces         | 4.65e+04    |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 39          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 124800      |
# | train/                  |             |
# |    approx_kl            | 0.010175976 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0302      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.996       |
# |    value_loss           | 0.0894      |
# -----------------------------------------
# Forces on test set: 47159.553223
# -----------------------------------------
# | forces                  | 1022.9673   |
# | rew_unnormalized        | -86671.82   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 2.095312    |
# | test set forces         | 4.72e+04    |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 40          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 128000      |
# | train/                  |             |
# |    approx_kl            | 0.009469353 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0178      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.995       |
# |    value_loss           | 0.0858      |
# -----------------------------------------
# Forces on test set: 47466.994751
# -----------------------------------------
# | forces                  | 1010.91284  |
# | rew_unnormalized        | -70294.836  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 2.388717    |
# | test set forces         | 4.75e+04    |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 41          |
# |    time_elapsed         | 539         |
# |    total_timesteps      | 131200      |
# | train/                  |             |
# |    approx_kl            | 0.011245307 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0511      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.995       |
# |    value_loss           | 0.0857      |
# -----------------------------------------
# Forces on test set: 48106.263611
# -----------------------------------------
# | forces                  | 1031.9454   |
# | rew_unnormalized        | -81075.36   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 2.1391346   |
# | test set forces         | 4.81e+04    |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 42          |
# |    time_elapsed         | 551         |
# |    total_timesteps      | 134400      |
# | train/                  |             |
# |    approx_kl            | 0.014851035 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0113      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.994       |
# |    value_loss           | 0.0915      |
# -----------------------------------------
# Forces on test set: 48850.264221
# -----------------------------------------
# | forces                  | 1015.82477  |
# | rew_unnormalized        | -69476.16   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 2.3382192   |
# | test set forces         | 4.89e+04    |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 43          |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 137600      |
# | train/                  |             |
# |    approx_kl            | 0.008968687 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00907     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00979    |
# |    std                  | 0.994       |
# |    value_loss           | 0.0788      |
# -----------------------------------------
# Forces on test set: 49261.194031
# -----------------------------------------
# | forces                  | 1020.71765  |
# | rew_unnormalized        | -76084.9    |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 2.1757858   |
# | test set forces         | 4.93e+04    |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 44          |
# |    time_elapsed         | 576         |
# |    total_timesteps      | 140800      |
# | train/                  |             |
# |    approx_kl            | 0.007578764 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0384      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00965    |
# |    std                  | 0.993       |
# |    value_loss           | 0.0668      |
# -----------------------------------------
# Forces on test set: 50042.563110
# -----------------------------------------
# | forces                  | 1025.7861   |
# | rew_unnormalized        | -66791.336  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 2.3368688   |
# | test set forces         | 5e+04       |
# ...
# | test set forces         | 6.88e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 986         |
# |    time_elapsed         | 12365       |
# |    total_timesteps      | 3155200     |
# | train/                  |             |
# |    approx_kl            | 0.049877357 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.4       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00366    |
# |    n_updates            | 9850        |
# |    policy_gradient_loss | -0.023      |
# |    std                  | 0.734       |
# |    value_loss           | 0.00779     |
# -----------------------------------------
# Forces on test set: 68567.860107
# -----------------------------------------
# | forces                  | 935.0701    |
# | rew_unnormalized        | -4966.974   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2159688   |
# | test set forces         | 6.86e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 987         |
# |    time_elapsed         | 12378       |
# |    total_timesteps      | 3158400     |
# | train/                  |             |
# |    approx_kl            | 0.033376027 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.4       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00481    |
# |    n_updates            | 9860        |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.734       |
# |    value_loss           | 0.0275      |
# -----------------------------------------
# Forces on test set: 68016.729370
# -----------------------------------------
# | forces                  | 960.91235   |
# | rew_unnormalized        | -4796.649   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2312193   |
# | test set forces         | 6.8e+04     |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 988         |
# |    time_elapsed         | 12391       |
# |    total_timesteps      | 3161600     |
# | train/                  |             |
# |    approx_kl            | 0.038174085 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.4       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0371     |
# |    n_updates            | 9870        |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.734       |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# Forces on test set: 68155.312256
# -----------------------------------------
# | forces                  | 930.7539    |
# | rew_unnormalized        | -4295.876   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2772298   |
# | test set forces         | 6.82e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 989         |
# |    time_elapsed         | 12404       |
# |    total_timesteps      | 3164800     |
# | train/                  |             |
# |    approx_kl            | 0.029836204 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.4       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0181     |
# |    n_updates            | 9880        |
# |    policy_gradient_loss | -0.0217     |
# |    std                  | 0.733       |
# |    value_loss           | 0.00647     |
# -----------------------------------------
# Forces on test set: 68099.497681
# -----------------------------------------
# | forces                  | 923.20807   |
# | rew_unnormalized        | -4840.2314  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2258444   |
# | test set forces         | 6.81e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 990         |
# |    time_elapsed         | 12417       |
# |    total_timesteps      | 3168000     |
# | train/                  |             |
# |    approx_kl            | 0.030297093 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.3       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0392     |
# |    n_updates            | 9890        |
# |    policy_gradient_loss | -0.0244     |
# |    std                  | 0.732       |
# |    value_loss           | 0.00545     |
# -----------------------------------------
# Forces on test set: 68579.605957
# ----------------------------------------
# | forces                  | 971.1364   |
# | rew_unnormalized        | -5789.9233 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.1366917  |
# | test set forces         | 6.86e+04   |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 991        |
# |    time_elapsed         | 12430      |
# |    total_timesteps      | 3171200    |
# | train/                  |            |
# |    approx_kl            | 0.04228607 |
# |    clip_fraction        | 0.378      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -35.3      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0291    |
# |    n_updates            | 9900       |
# |    policy_gradient_loss | -0.0215    |
# |    std                  | 0.732      |
# |    value_loss           | 0.00873    |
# ----------------------------------------
# Forces on test set: 68094.510864
# -----------------------------------------
# | forces                  | 945.14435   |
# | rew_unnormalized        | -5081.754   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2021621   |
# | test set forces         | 6.81e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 992         |
# |    time_elapsed         | 12443       |
# |    total_timesteps      | 3174400     |
# | train/                  |             |
# |    approx_kl            | 0.042175476 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.3       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0405     |
# |    n_updates            | 9910        |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.732       |
# |    value_loss           | 0.0155      |
# -----------------------------------------
# Forces on test set: 67830.621216
# -----------------------------------------
# | forces                  | 936.4048    |
# | rew_unnormalized        | -4722.0327  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.235122    |
# | test set forces         | 6.78e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 993         |
# |    time_elapsed         | 12456       |
# |    total_timesteps      | 3177600     |
# | train/                  |             |
# |    approx_kl            | 0.034487907 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.3       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0373     |
# |    n_updates            | 9920        |
# |    policy_gradient_loss | -0.028      |
# |    std                  | 0.732       |
# |    value_loss           | 0.0079      |
# -----------------------------------------
# Forces on test set: 67934.624512
# -----------------------------------------
# | forces                  | 936.6354    |
# | rew_unnormalized        | -5056.4937  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.203294    |
# | test set forces         | 6.79e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 994         |
# |    time_elapsed         | 12469       |
# |    total_timesteps      | 3180800     |
# | train/                  |             |
# |    approx_kl            | 0.038654134 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.3       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00474    |
# |    n_updates            | 9930        |
# |    policy_gradient_loss | -0.0256     |
# |    std                  | 0.731       |
# |    value_loss           | 0.00465     |
# -----------------------------------------
# Forces on test set: 67819.589600
# -----------------------------------------
# | forces                  | 947.80743   |
# | rew_unnormalized        | -4722.0137  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2339096   |
# | test set forces         | 6.78e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 995         |
# |    time_elapsed         | 12482       |
# |    total_timesteps      | 3184000     |
# | train/                  |             |
# |    approx_kl            | 0.031318005 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.3       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0251     |
# |    n_updates            | 9940        |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.731       |
# |    value_loss           | 0.00967     |
# -----------------------------------------
# Forces on test set: 68074.205688
# ----------------------------------------
# | forces                  | 966.51917  |
# | rew_unnormalized        | -5194.463  |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.1890911  |
# | test set forces         | 6.81e+04   |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 996        |
# |    time_elapsed         | 12495      |
# |    total_timesteps      | 3187200    |
# | train/                  |            |
# |    approx_kl            | 0.04352279 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -35.3      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0114    |
# |    n_updates            | 9950       |
# |    policy_gradient_loss | -0.0279    |
# |    std                  | 0.732      |
# |    value_loss           | 0.0053     |
# ----------------------------------------
# Forces on test set: 67995.042847
# -----------------------------------------
# | forces                  | 943.0871    |
# | rew_unnormalized        | -5029.5786  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2039542   |
# | test set forces         | 6.8e+04     |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 997         |
# |    time_elapsed         | 12508       |
# |    total_timesteps      | 3190400     |
# | train/                  |             |
# |    approx_kl            | 0.036938313 |
# |    clip_fraction        | 0.372       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.3       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.026      |
# |    n_updates            | 9960        |
# |    policy_gradient_loss | -0.024      |
# |    std                  | 0.732       |
# |    value_loss           | 0.00899     |
# -----------------------------------------
# Forces on test set: 67826.794556
# -----------------------------------------
# | forces                  | 955.4903    |
# | rew_unnormalized        | -4798.4966  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2249677   |
# | test set forces         | 6.78e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 998         |
# |    time_elapsed         | 12521       |
# |    total_timesteps      | 3193600     |
# | train/                  |             |
# |    approx_kl            | 0.043538667 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.3       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0379     |
# |    n_updates            | 9970        |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.732       |
# |    value_loss           | 0.00739     |
# -----------------------------------------
# Forces on test set: 67792.084961
# -----------------------------------------
# | forces                  | 941.2346    |
# | rew_unnormalized        | -4834.82    |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2209321   |
# | test set forces         | 6.78e+04    |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 999         |
# |    time_elapsed         | 12534       |
# |    total_timesteps      | 3196800     |
# | train/                  |             |
# |    approx_kl            | 0.043710966 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.3       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0259     |
# |    n_updates            | 9980        |
# |    policy_gradient_loss | -0.0245     |
# |    std                  | 0.731       |
# |    value_loss           | 0.00549     |
# -----------------------------------------
# Forces on test set: 68053.171753
# Storing agent and hyperparameters to disk...
# ----------------------------------------
# | forces                  | 967.58154  |
# | rew_unnormalized        | -5054.3325 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.1997501  |
# | test set forces         | 6.81e+04   |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 1000       |
# |    time_elapsed         | 12547      |
# |    total_timesteps      | 3200000    |
# | train/                  |            |
# |    approx_kl            | 0.02936296 |
# |    clip_fraction        | 0.345      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -35.3      |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0217    |
# |    n_updates            | 9990       |
# |    policy_gradient_loss | -0.0189    |
# |    std                  | 0.731      |
# |    value_loss           | 0.00688    |
# ----------------------------------------
# Storing agent and hyperparameters to disk...

# %% [markdown]
# Let's see how the reward evolved during training

# %%
trainer.plot()

# %% [markdown]
# Run the cell below to open the tensorboard logs. If necessary, replace the path with the one leading to the log folder of your experiment

# %%
# %load_ext tensorboard
# %tensorboard --logdir rl-models/ControlBurgersBench3/tensorboard-log

# %% [markdown]
# Now we can take a look at how the agent is performing:

# %%
env = trainer.env

obs = env.reset()
bplt.burgers_figure('RL Reconstruction')
plt.plot(obs[0][:,0], color=bplt.gradient_color(0, step_count+1), linewidth=0.8)
plt.legend(['Initial state in dark red, final state in dark blue,'])
plt.ylim(-2, 2)
for frame in range(1, step_count):
    act = trainer.predict(obs, deterministic=True)
    obs, _, _, _ = env.step(act)
    plt.plot(obs[0][:,0], color=bplt.gradient_color(frame, step_count+1), linewidth=0.8)
plt.plot(env.goal_state.velocity.data[0,:,0])
