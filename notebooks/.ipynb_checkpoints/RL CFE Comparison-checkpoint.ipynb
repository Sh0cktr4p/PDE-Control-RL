# %% [markdown]
# # Comparison Reinforcement Learning vs. CFE Approach

# %% [markdown]
# In this notebook, the results of using Reinforcement Learning for controlling Burgers' Equation are compared to a supervised control force estimator approach using a differentiable physics loss function, which was proposed by Holl et al. [2020](https://ge.in.tum.de/publications/2020-iclr-holl). Both methods use the differentiable PDE solver [Φ<sub>Flow</sub>](https://github.com/tum-pbs/PhiFlow).
# The reinforcement learning method also uses the [stable_baselines3](https://github.com/DLR-RM/stable-baselines3) RL framework and works with the [PPO](https://arxiv.org/abs/1707.06347v2) learning algorithm.

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext tensorboard
import sys; sys.path.append('../src'); sys.path.append('../PDE-Control/PhiFlow'); sys.path.append('../PDE-Control/src')
from phi.flow import *
import burgers_plots as bplt
import matplotlib.pyplot as plt
from envs.burgers_util import GaussianClash, GaussianForce

# %% [markdown]
# ## Data generation

# %% [markdown]
# At first, we will generate a suite of test scenes on which both methods will be evaluated.

# %%
domain = Domain([32], box=box[0:1])
viscosity = 0.003
step_count = 32
dt = 0.03
diffusion_substeps = 1

data_path = 'forced-burgers-clash'
scene_count = 1000
batch_size = 100

train_range = range(200, 1000)
val_range = range(100, 200)
test_range = range(0, 100)

# %%
for batch_index in range(scene_count // batch_size):
    scene = Scene.create(data_path, count=batch_size)
    print(scene)
    world = World()
    u0 = BurgersVelocity(
        domain, 
        velocity=GaussianClash(batch_size), 
        viscosity=viscosity, 
        batch_size=batch_size, 
        name='burgers'
    )
    u = world.add(u0, physics=Burgers(diffusion_substeps=diffusion_substeps))
    force = world.add(FieldEffect(GaussianForce(batch_size), ['velocity']))
    scene.write(world.state, frame=0)
    for frame in range(1, step_count + 1):
        world.step(dt=dt)
        scene.write(world.state, frame=frame)
# Out:
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/phi/data/fluidformat.py:293: UserWarning:
#
# Failed to copy calling script to scene during Scene.create().
# Cause: [Errno 2] No such file or directory: '<ipython-input-3-fc5d3be44e31>'
# forced-burgers-clash/sim_000000
# forced-burgers-clash/sim_000100
# forced-burgers-clash/sim_000200
# forced-burgers-clash/sim_000300
# forced-burgers-clash/sim_000400
# forced-burgers-clash/sim_000500
# forced-burgers-clash/sim_000600
# forced-burgers-clash/sim_000700
# forced-burgers-clash/sim_000800
# forced-burgers-clash/sim_000900

# %% [markdown]
# ## Reinforcement Learning initialization

# %%
from experiment import BurgersTraining
# Out:
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /home/felix/anaconda3/envs/phiflow/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.

# %%
n_envs = 10 # On how many environments to train in parallel, load balancing
final_reward_factor = step_count # How hard to punish the agent for not reaching the goal if that is the case
steps_per_rollout = step_count * 10 # How many steps to collect per environment between agent updates
n_epochs = 10 # How many epochs to perform during agent update
learning_rate = 1e-4 # Learning rate for agent updates
rl_batch_size = 128 # Batch size for agent updates

# %% [markdown]
# To start training, we create a trainer object, which manages the environment and the agent internally. Additionally, a directory for storing models, logs, and hyperparameters is created. This way, training can be continued at any later point using the same configuration. If the model folder specified in exp_name already exists, the agent within is loaded. Otherwise, a new agent is created

# %%
rl_trainer = BurgersTraining(
    exp_name='../networks/rl-models/ControlBurgersBench',
    domain=domain,
    viscosity=viscosity,
    step_count=step_count,
    dt=dt,
    diffusion_substeps=diffusion_substeps,
    n_envs=n_envs,
    final_reward_factor=final_reward_factor,
    steps_per_rollout=steps_per_rollout,
    n_epochs=n_epochs,
    learning_rate=learning_rate,
    batch_size=rl_batch_size,
    test_path=data_path,
    test_range=test_range,
)
# Out:
# Loading existing agent from ../networks/rl-models/ControlBurgersBench/agent.zip

# %% [markdown]
# Now we are set up to start training the agent. The next line will take quite some time to execute, so grab a coffee or take your dog for a walk or so.
#
# n_rollouts denotes the length of the training
#
# save_freq specifies the number of epochs after which the stored model is overwritten

# %%
# Execute to run tensorboard
# %tensorboard --logdir ../networks/rl-models/ControlBurgersBench/tensorboard-log

# %%
rl_trainer.train(n_rollouts=1000, save_freq=50)
# Out:
# Logging to ../networks/rl-models/ControlBurgersBench/tensorboard-log/PPO_2
# Storing agent and hyperparameters to disk...
# Forces on test set: 595.131836
# -----------------------------------
# | forces             | 849.33685  |
# | rew_unnormalized   | -5194.8433 |
# | rollout/           |            |
# |    ep_len_mean     | 32.0       |
# |    ep_rew_mean     | 1.2473397  |
# | test set forces    | 595        |
# | time/              |            |
# |    fps             | 684        |
# |    iterations      | 1          |
# |    time_elapsed    | 4          |
# |    total_timesteps | 3200       |
# -----------------------------------
# Forces on test set: 593.975977
# -----------------------------------------
# | forces                  | 832.9147    |
# | rew_unnormalized        | -5046.2085  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2572876   |
# | test set forces         | 594         |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 2           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.038249575 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.2       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.038      |
# |    n_updates            | 10010       |
# |    policy_gradient_loss | -0.0258     |
# |    std                  | 0.663       |
# |    value_loss           | 0.00807     |
# -----------------------------------------
# Forces on test set: 593.097969
# -----------------------------------------
# | forces                  | 831.3303    |
# | rew_unnormalized        | -5022.942   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2583532   |
# | test set forces         | 593         |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 3           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 9600        |
# | train/                  |             |
# |    approx_kl            | 0.029427897 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.2       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0203     |
# |    n_updates            | 10020       |
# |    policy_gradient_loss | -0.0217     |
# |    std                  | 0.662       |
# |    value_loss           | 0.00492     |
# -----------------------------------------
# Forces on test set: 593.210664
# ----------------------------------------
# | forces                  | 831.8215   |
# | rew_unnormalized        | -4872.8164 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.2684531  |
# | test set forces         | 593        |
# | time/                   |            |
# |    fps                  | 298        |
# |    iterations           | 4          |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 12800      |
# | train/                  |            |
# |    approx_kl            | 0.04227384 |
# |    clip_fraction        | 0.359      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -32.1      |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0391    |
# |    n_updates            | 10030      |
# |    policy_gradient_loss | -0.0191    |
# |    std                  | 0.662      |
# |    value_loss           | 0.00711    |
# ----------------------------------------
# Forces on test set: 595.539297
# -----------------------------------------
# | forces                  | 815.4179    |
# | rew_unnormalized        | -4347.592   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3054675   |
# | test set forces         | 596         |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 5           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.036669433 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.1       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.056      |
# |    n_updates            | 10040       |
# |    policy_gradient_loss | -0.0314     |
# |    std                  | 0.662       |
# |    value_loss           | 0.00596     |
# -----------------------------------------
# Forces on test set: 593.356133
# ----------------------------------------
# | forces                  | 832.4757   |
# | rew_unnormalized        | -5046.4395 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.2546957  |
# | test set forces         | 593        |
# | time/                   |            |
# |    fps                  | 280        |
# |    iterations           | 6          |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 19200      |
# | train/                  |            |
# |    approx_kl            | 0.03660148 |
# |    clip_fraction        | 0.359      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -32.1      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0175    |
# |    n_updates            | 10050      |
# |    policy_gradient_loss | -0.0239    |
# |    std                  | 0.661      |
# |    value_loss           | 0.00404    |
# ----------------------------------------
# Forces on test set: 592.784648
# ----------------------------------------
# | forces                  | 819.15485  |
# | rew_unnormalized        | -3966.3313 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.3315747  |
# | test set forces         | 593        |
# | time/                   |            |
# |    fps                  | 276        |
# |    iterations           | 7          |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 22400      |
# | train/                  |            |
# |    approx_kl            | 0.03963224 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -32.1      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0346    |
# |    n_updates            | 10060      |
# |    policy_gradient_loss | -0.0273    |
# |    std                  | 0.661      |
# |    value_loss           | 0.00772    |
# ----------------------------------------
# Forces on test set: 591.661797
# ----------------------------------------
# | forces                  | 848.74097  |
# | rew_unnormalized        | -5520.9546 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.2192937  |
# | test set forces         | 592        |
# | time/                   |            |
# |    fps                  | 273        |
# |    iterations           | 8          |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.03820001 |
# |    clip_fraction        | 0.373      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -32        |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0483    |
# |    n_updates            | 10070      |
# |    policy_gradient_loss | -0.0252    |
# |    std                  | 0.66       |
# |    value_loss           | 0.00415    |
# ----------------------------------------
# Forces on test set: 592.156914
# -----------------------------------------
# | forces                  | 825.62976   |
# | rew_unnormalized        | -4167.943   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3158803   |
# | test set forces         | 592         |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 9           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 28800       |
# | train/                  |             |
# |    approx_kl            | 0.031472854 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32         |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0273     |
# |    n_updates            | 10080       |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.66        |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# Forces on test set: 593.017148
# -----------------------------------------
# | forces                  | 866.6545    |
# | rew_unnormalized        | -4416.462   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2973703   |
# | test set forces         | 593         |
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 10          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.044481803 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32         |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0557     |
# |    n_updates            | 10090       |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.66        |
# |    value_loss           | 0.00334     |
# -----------------------------------------
# Forces on test set: 593.128633
# ----------------------------------------
# | forces                  | 833.71063  |
# | rew_unnormalized        | -4482.308  |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.2919888  |
# | test set forces         | 593        |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 11         |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 35200      |
# | train/                  |            |
# |    approx_kl            | 0.04894846 |
# |    clip_fraction        | 0.376      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -32        |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0603    |
# |    n_updates            | 10100      |
# |    policy_gradient_loss | -0.0309    |
# |    std                  | 0.659      |
# |    value_loss           | 0.00443    |
# ----------------------------------------
# Forces on test set: 596.434102
# -----------------------------------------
# | forces                  | 819.1038    |
# | rew_unnormalized        | -4241.2236  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3086901   |
# | test set forces         | 596         |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 12          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 38400       |
# | train/                  |             |
# |    approx_kl            | 0.027560892 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32         |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.053      |
# |    n_updates            | 10110       |
# |    policy_gradient_loss | -0.0256     |
# |    std                  | 0.659       |
# |    value_loss           | 0.00652     |
# -----------------------------------------
# Forces on test set: 595.186172
# -----------------------------------------
# | forces                  | 810.0018    |
# | rew_unnormalized        | -4260.2827  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3066795   |
# | test set forces         | 595         |
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 13          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 41600       |
# | train/                  |             |
# |    approx_kl            | 0.035881218 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32         |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.029      |
# |    n_updates            | 10120       |
# |    policy_gradient_loss | -0.0245     |
# |    std                  | 0.658       |
# |    value_loss           | 0.00396     |
# -----------------------------------------
# Forces on test set: 597.675195
# -----------------------------------------
# | forces                  | 809.06354   |
# | rew_unnormalized        | -4213.726   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3093622   |
# | test set forces         | 598         |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 14          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 44800       |
# | train/                  |             |
# |    approx_kl            | 0.026053704 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.9       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0365     |
# |    n_updates            | 10130       |
# |    policy_gradient_loss | -0.024      |
# |    std                  | 0.657       |
# |    value_loss           | 0.00397     |
# -----------------------------------------
# Forces on test set: 597.597500
# ----------------------------------------
# | forces                  | 790.58344  |
# | rew_unnormalized        | -4015.9207 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.3229578  |
# | test set forces         | 598        |
# | time/                   |            |
# |    fps                  | 240        |
# |    iterations           | 15         |
# |    time_elapsed         | 199        |
# |    total_timesteps      | 48000      |
# | train/                  |            |
# |    approx_kl            | 0.04090451 |
# |    clip_fraction        | 0.363      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.9      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0395    |
# |    n_updates            | 10140      |
# |    policy_gradient_loss | -0.0252    |
# |    std                  | 0.657      |
# |    value_loss           | 0.00409    |
# ----------------------------------------
# Forces on test set: 598.791797
# -----------------------------------------
# | forces                  | 842.6797    |
# | rew_unnormalized        | -4386.137   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2956238   |
# | test set forces         | 599         |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 16          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.056229558 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.9       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0712     |
# |    n_updates            | 10150       |
# |    policy_gradient_loss | -0.0305     |
# |    std                  | 0.657       |
# |    value_loss           | 0.00287     |
# -----------------------------------------
# Forces on test set: 594.955469
# ----------------------------------------
# | forces                  | 810.1331   |
# | rew_unnormalized        | -5107.4175 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.2429845  |
# | test set forces         | 595        |
# | time/                   |            |
# |    fps                  | 234        |
# |    iterations           | 17         |
# |    time_elapsed         | 231        |
# |    total_timesteps      | 54400      |
# | train/                  |            |
# |    approx_kl            | 0.03750724 |
# |    clip_fraction        | 0.359      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.9      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0225    |
# |    n_updates            | 10160      |
# |    policy_gradient_loss | -0.0348    |
# |    std                  | 0.656      |
# |    value_loss           | 0.00368    |
# ----------------------------------------
# Forces on test set: 594.329492
# ----------------------------------------
# | forces                  | 762.35876  |
# | rew_unnormalized        | -3734.5288 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.3414094  |
# | test set forces         | 594        |
# | time/                   |            |
# |    fps                  | 232        |
# |    iterations           | 18         |
# |    time_elapsed         | 247        |
# |    total_timesteps      | 57600      |
# | train/                  |            |
# |    approx_kl            | 0.04525759 |
# |    clip_fraction        | 0.406      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.8      |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0172    |
# |    n_updates            | 10170      |
# |    policy_gradient_loss | -0.0151    |
# |    std                  | 0.656      |
# |    value_loss           | 0.0154     |
# ----------------------------------------
# Forces on test set: 593.081133
# -----------------------------------------
# | forces                  | 810.84564   |
# | rew_unnormalized        | -4519.8354  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2840618   |
# | test set forces         | 593         |
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 19          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 60800       |
# | train/                  |             |
# |    approx_kl            | 0.027858298 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.9       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0561     |
# |    n_updates            | 10180       |
# |    policy_gradient_loss | -0.0244     |
# |    std                  | 0.656       |
# |    value_loss           | 0.00324     |
# -----------------------------------------
# Forces on test set: 593.088398
# -----------------------------------------
# | forces                  | 799.7422    |
# | rew_unnormalized        | -4069.0276  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3159784   |
# | test set forces         | 593         |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 20          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 64000       |
# | train/                  |             |
# |    approx_kl            | 0.029663587 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.8       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0338     |
# |    n_updates            | 10190       |
# |    policy_gradient_loss | -0.0244     |
# |    std                  | 0.656       |
# |    value_loss           | 0.00774     |
# -----------------------------------------
# Forces on test set: 592.428398
# -----------------------------------------
# | forces                  | 849.4213    |
# | rew_unnormalized        | -4608.733   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.276327    |
# | test set forces         | 592         |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 21          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 67200       |
# | train/                  |             |
# |    approx_kl            | 0.058394086 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.8       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00616    |
# |    n_updates            | 10200       |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.655       |
# |    value_loss           | 0.00762     |
# -----------------------------------------
# Forces on test set: 592.488633
# -----------------------------------------
# | forces                  | 787.9534    |
# | rew_unnormalized        | -4377.996   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2924142   |
# | test set forces         | 592         |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 22          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 70400       |
# | train/                  |             |
# |    approx_kl            | 0.050068103 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.8       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0475     |
# |    n_updates            | 10210       |
# |    policy_gradient_loss | -0.0317     |
# |    std                  | 0.655       |
# |    value_loss           | 0.00512     |
# -----------------------------------------
# Forces on test set: 594.223906
# ----------------------------------------
# | forces                  | 859.9843   |
# | rew_unnormalized        | -4986.6514 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.2477255  |
# | test set forces         | 594        |
# | time/                   |            |
# |    fps                  | 224        |
# |    iterations           | 23         |
# |    time_elapsed         | 328        |
# |    total_timesteps      | 73600      |
# | train/                  |            |
# |    approx_kl            | 0.03776101 |
# |    clip_fraction        | 0.373      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.8      |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0326    |
# |    n_updates            | 10220      |
# |    policy_gradient_loss | -0.0189    |
# |    std                  | 0.655      |
# |    value_loss           | 0.0109     |
# ----------------------------------------
# Forces on test set: 592.098242
# -----------------------------------------
# | forces                  | 817.7429    |
# | rew_unnormalized        | -4336.9736  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2941484   |
# | test set forces         | 592         |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 24          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 76800       |
# | train/                  |             |
# |    approx_kl            | 0.049995508 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.8       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0354     |
# |    n_updates            | 10230       |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 0.655       |
# |    value_loss           | 0.00619     |
# -----------------------------------------
# Forces on test set: 592.059531
# ----------------------------------------
# | forces                  | 815.32446  |
# | rew_unnormalized        | -3734.248  |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.33712    |
# | test set forces         | 592        |
# | time/                   |            |
# |    fps                  | 220        |
# |    iterations           | 25         |
# |    time_elapsed         | 363        |
# |    total_timesteps      | 80000      |
# | train/                  |            |
# |    approx_kl            | 0.04665651 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.8      |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0305    |
# |    n_updates            | 10240      |
# |    policy_gradient_loss | -0.0226    |
# |    std                  | 0.654      |
# |    value_loss           | 0.00649    |
# ----------------------------------------
# Forces on test set: 593.726055
# -----------------------------------------
# | forces                  | 830.2509    |
# | rew_unnormalized        | -4025.6343  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3153827   |
# | test set forces         | 594         |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 26          |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 83200       |
# | train/                  |             |
# |    approx_kl            | 0.047600485 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.8       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0429     |
# |    n_updates            | 10250       |
# |    policy_gradient_loss | -0.0181     |
# |    std                  | 0.654       |
# |    value_loss           | 0.00733     |
# -----------------------------------------
# Forces on test set: 590.660391
# -----------------------------------------
# | forces                  | 783.3924    |
# | rew_unnormalized        | -3866.3806  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3262465   |
# | test set forces         | 591         |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 27          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 86400       |
# | train/                  |             |
# |    approx_kl            | 0.040500604 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.7       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0255     |
# |    n_updates            | 10260       |
# |    policy_gradient_loss | -0.0266     |
# |    std                  | 0.653       |
# |    value_loss           | 0.00432     |
# -----------------------------------------
# Forces on test set: 592.644609
# -----------------------------------------
# | forces                  | 822.2388    |
# | rew_unnormalized        | -4226.1353  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2995137   |
# | test set forces         | 593         |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 28          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 89600       |
# | train/                  |             |
# |    approx_kl            | 0.026284847 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.7       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0326     |
# |    n_updates            | 10270       |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.653       |
# |    value_loss           | 0.0141      |
# -----------------------------------------
# Forces on test set: 591.672422
# ----------------------------------------
# | forces                  | 793.95764  |
# | rew_unnormalized        | -4183.6816 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.3019813  |
# | test set forces         | 592        |
# | time/                   |            |
# |    fps                  | 214        |
# |    iterations           | 29         |
# |    time_elapsed         | 433        |
# |    total_timesteps      | 92800      |
# | train/                  |            |
# |    approx_kl            | 0.02883947 |
# |    clip_fraction        | 0.364      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.7      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.055     |
# |    n_updates            | 10280      |
# |    policy_gradient_loss | -0.0232    |
# |    std                  | 0.652      |
# |    value_loss           | 0.0061     |
# ----------------------------------------
# Forces on test set: 592.003281
# -----------------------------------------
# | forces                  | 811.275     |
# | rew_unnormalized        | -5031.619   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.239783    |
# | test set forces         | 592         |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 30          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 96000       |
# | train/                  |             |
# |    approx_kl            | 0.043435108 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.7       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0435     |
# |    n_updates            | 10290       |
# |    policy_gradient_loss | -0.0242     |
# |    std                  | 0.652       |
# |    value_loss           | 0.00623     |
# -----------------------------------------
# Forces on test set: 593.581133
# -----------------------------------------
# | forces                  | 806.44525   |
# | rew_unnormalized        | -3929.1506  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3192426   |
# | test set forces         | 594         |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 31          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 99200       |
# | train/                  |             |
# |    approx_kl            | 0.019223213 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.7       |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0383     |
# |    n_updates            | 10300       |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.653       |
# |    value_loss           | 0.0172      |
# -----------------------------------------
# Forces on test set: 594.995000
# ----------------------------------------
# | forces                  | 801.991    |
# | rew_unnormalized        | -4307.5522 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.2911499  |
# | test set forces         | 595        |
# | time/                   |            |
# |    fps                  | 211        |
# |    iterations           | 32         |
# |    time_elapsed         | 484        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.0562551  |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.7      |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0479    |
# |    n_updates            | 10310      |
# |    policy_gradient_loss | -0.0246    |
# |    std                  | 0.652      |
# |    value_loss           | 0.00354    |
# ----------------------------------------
# Forces on test set: 595.876250
# ----------------------------------------
# | forces                  | 824.685    |
# | rew_unnormalized        | -3933.2202 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.3176835  |
# | test set forces         | 596        |
# | time/                   |            |
# |    fps                  | 210        |
# |    iterations           | 33         |
# |    time_elapsed         | 502        |
# |    total_timesteps      | 105600     |
# | train/                  |            |
# |    approx_kl            | 0.0239743  |
# |    clip_fraction        | 0.346      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.6      |
# |    explained_variance   | 0.828      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0268    |
# |    n_updates            | 10320      |
# |    policy_gradient_loss | -0.0231    |
# |    std                  | 0.652      |
# |    value_loss           | 0.0191     |
# ----------------------------------------
# Forces on test set: 595.161641
# ----------------------------------------
# | forces                  | 826.7713   |
# | rew_unnormalized        | -4103.416  |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.3046718  |
# | test set forces         | 595        |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 34         |
# |    time_elapsed         | 520        |
# |    total_timesteps      | 108800     |
# | train/                  |            |
# |    approx_kl            | 0.04780064 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.6      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0512    |
# |    n_updates            | 10330      |
# |    policy_gradient_loss | -0.0253    |
# |    std                  | 0.652      |
# |    value_loss           | 0.00507    |
# ----------------------------------------
# Forces on test set: 596.624766
# -----------------------------------------
# | forces                  | 814.79596   |
# | rew_unnormalized        | -3849.3787  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3225025   |
# | test set forces         | 597         |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 35          |
# |    time_elapsed         | 539         |
# |    total_timesteps      | 112000      |
# | train/                  |             |
# |    approx_kl            | 0.031191062 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.6       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0342     |
# |    n_updates            | 10340       |
# |    policy_gradient_loss | -0.0276     |
# |    std                  | 0.652       |
# |    value_loss           | 0.00516     |
# -----------------------------------------
# Forces on test set: 597.913125
# -----------------------------------------
# | forces                  | 823.4536    |
# | rew_unnormalized        | -4633.373   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.264813    |
# | test set forces         | 598         |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 36          |
# |    time_elapsed         | 559         |
# |    total_timesteps      | 115200      |
# | train/                  |             |
# |    approx_kl            | 0.055228386 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.6       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0501     |
# |    n_updates            | 10350       |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.651       |
# |    value_loss           | 0.0034      |
# -----------------------------------------
# Forces on test set: 596.662148
# -----------------------------------------
# | forces                  | 825.6168    |
# | rew_unnormalized        | -4197.934   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2958962   |
# | test set forces         | 597         |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 37          |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 118400      |
# | train/                  |             |
# |    approx_kl            | 0.031164952 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.6       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0462     |
# |    n_updates            | 10360       |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.651       |
# |    value_loss           | 0.00838     |
# -----------------------------------------
# Forces on test set: 596.136992
# -----------------------------------------
# | forces                  | 815.7093    |
# | rew_unnormalized        | -4034.87    |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.307157    |
# | test set forces         | 596         |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 38          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 121600      |
# | train/                  |             |
# |    approx_kl            | 0.037771594 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.6       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0428     |
# |    n_updates            | 10370       |
# |    policy_gradient_loss | -0.022      |
# |    std                  | 0.651       |
# |    value_loss           | 0.00591     |
# -----------------------------------------
# Forces on test set: 598.240859
# -----------------------------------------
# | forces                  | 821.15015   |
# | rew_unnormalized        | -4340.671   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2842411   |
# | test set forces         | 598         |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 39          |
# |    time_elapsed         | 619         |
# |    total_timesteps      | 124800      |
# | train/                  |             |
# |    approx_kl            | 0.055046156 |
# |    clip_fraction        | 0.411       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.6       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0246     |
# |    n_updates            | 10380       |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.651       |
# |    value_loss           | 0.00594     |
# -----------------------------------------
# Forces on test set: 596.727969
# -----------------------------------------
# | forces                  | 817.5731    |
# | rew_unnormalized        | -5095.9014  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2285663   |
# | test set forces         | 597         |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 40          |
# |    time_elapsed         | 636         |
# |    total_timesteps      | 128000      |
# | train/                  |             |
# |    approx_kl            | 0.025817752 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.6       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0344     |
# |    n_updates            | 10390       |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.65        |
# |    value_loss           | 0.00664     |
# -----------------------------------------
# Forces on test set: 594.667500
# -----------------------------------------
# | forces                  | 807.1337    |
# | rew_unnormalized        | -3775.8494  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.3242462   |
# | test set forces         | 595         |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 41          |
# |    time_elapsed         | 652         |
# |    total_timesteps      | 131200      |
# | train/                  |             |
# |    approx_kl            | 0.035126686 |
# |    clip_fraction        | 0.416       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.5       |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0246     |
# |    n_updates            | 10400       |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.65        |
# |    value_loss           | 0.0167      |
# -----------------------------------------
# Forces on test set: 593.203945
# ----------------------------------------
# | forces                  | 827.69946  |
# | rew_unnormalized        | -4761.662  |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.2516557  |
# | test set forces         | 593        |
# | time/                   |            |
# |    fps                  | 200        |
# |    iterations           | 42         |
# |    time_elapsed         | 669        |
# |    total_timesteps      | 134400     |
# | train/                  |            |
# |    approx_kl            | 0.04635129 |
# |    clip_fraction        | 0.385      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.5      |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0228    |
# |    n_updates            | 10410      |
# |    policy_gradient_loss | -0.027     |
# |    std                  | 0.649      |
# |    value_loss           | 0.00255    |
# ----------------------------------------
# Forces on test set: 592.536680
# ----------------------------------------
# | forces                  | 815.7537   |
# | rew_unnormalized        | -4244.1924 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.2888371  |
# | test set forces         | 593        |
# | time/                   |            |
# |    fps                  | 200        |
# |    iterations           | 43         |
# |    time_elapsed         | 684        |
# |    total_timesteps      | 137600     |
# | train/                  |            |
# |    approx_kl            | 0.05750114 |
# |    clip_fraction        | 0.413      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.5      |
# |    explained_variance   | 0.92       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.034     |
# |    n_updates            | 10420      |
# |    policy_gradient_loss | -0.0257    |
# |    std                  | 0.649      |
# |    value_loss           | 0.0126     |
# ----------------------------------------
# Forces on test set: 595.267539
# ----------------------------------------
# | forces                  | 858.9433   |
# | rew_unnormalized        | -4779.7    |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.2491008  |
# | test set forces         | 595        |
# | time/                   |            |
# |    fps                  | 200        |
# |    iterations           | 44         |
# |    time_elapsed         | 701        |
# |    total_timesteps      | 140800     |
# | train/                  |            |
# |    approx_kl            | 0.04692539 |
# |    clip_fraction        | 0.385      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.5      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0399    |
# |    n_updates            | 10430      |
# |    policy_gradient_loss | -0.0261    |
# |    std                  | 0.649      |
# |    value_loss           | 0.00603    |
# ----------------------------------------
# Forces on test set: 596.490742
# -----------------------------------------
# | forces                  | 846.8982    |
# | rew_unnormalized        | -5066.397   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.2275512   |
# | test set forces         | 596         |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 45          |
# |    time_elapsed         | 717         |
# |    total_timesteps      | 144000      |
# | train/                  |             |
# |    approx_kl            | 0.059329487 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.5       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0302     |
# |    n_updates            | 10440       |
# |    policy_gradient_loss | -0.0285     |
# |    std                  | 0.649       |
# |    value_loss           | 0.00658     |
# -----------------------------------------
# Forces on test set: 595.786914
# ----------------------------------------
# | forces                  | 831.6658   |
# | rew_unnormalized        | -4607.7954 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# ...
# ----------------------------------------
# | forces                  | 744.082    |
# | rew_unnormalized        | -2954.472  |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.0107522  |
# | test set forces         | 624        |
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 984        |
# |    time_elapsed         | 15579      |
# |    total_timesteps      | 3148800    |
# | train/                  |            |
# |    approx_kl            | 0.15348935 |
# |    clip_fraction        | 0.521      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.5      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0659    |
# |    n_updates            | 19830      |
# |    policy_gradient_loss | -0.029     |
# |    std                  | 0.432      |
# |    value_loss           | 0.00261    |
# ----------------------------------------
# Forces on test set: 625.166523
# -----------------------------------------
# | forces                  | 769.02814   |
# | rew_unnormalized        | -2560.6292  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.0501263   |
# | test set forces         | 625         |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 985         |
# |    time_elapsed         | 15593       |
# |    total_timesteps      | 3152000     |
# | train/                  |             |
# |    approx_kl            | 0.033601042 |
# |    clip_fraction        | 0.518       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.5       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00578     |
# |    n_updates            | 19840       |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.432       |
# |    value_loss           | 0.00644     |
# -----------------------------------------
# Forces on test set: 627.334180
# ----------------------------------------
# | forces                  | 731.12164  |
# | rew_unnormalized        | -3212.6387 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 0.98423624 |
# | test set forces         | 627        |
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 986        |
# |    time_elapsed         | 15607      |
# |    total_timesteps      | 3155200    |
# | train/                  |            |
# |    approx_kl            | 0.0707624  |
# |    clip_fraction        | 0.494      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.5      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0348    |
# |    n_updates            | 19850      |
# |    policy_gradient_loss | -0.0231    |
# |    std                  | 0.432      |
# |    value_loss           | 0.00352    |
# ----------------------------------------
# Forces on test set: 629.574453
# -----------------------------------------
# | forces                  | 684.2111    |
# | rew_unnormalized        | -2045.8074  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.1014524   |
# | test set forces         | 630         |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 987         |
# |    time_elapsed         | 15620       |
# |    total_timesteps      | 3158400     |
# | train/                  |             |
# |    approx_kl            | 0.057910543 |
# |    clip_fraction        | 0.528       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.4       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0396     |
# |    n_updates            | 19860       |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.431       |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# Forces on test set: 631.027227
# ----------------------------------------
# | forces                  | 721.1598   |
# | rew_unnormalized        | -2650.14   |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.0403011  |
# | test set forces         | 631        |
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 988        |
# |    time_elapsed         | 15634      |
# |    total_timesteps      | 3161600    |
# | train/                  |            |
# |    approx_kl            | 0.12246555 |
# |    clip_fraction        | 0.528      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.4      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0441    |
# |    n_updates            | 19870      |
# |    policy_gradient_loss | -0.0298    |
# |    std                  | 0.431      |
# |    value_loss           | 0.00178    |
# ----------------------------------------
# Forces on test set: 630.952969
# ----------------------------------------
# | forces                  | 754.8561   |
# | rew_unnormalized        | -3157.554  |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 0.98892456 |
# | test set forces         | 631        |
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 989        |
# |    time_elapsed         | 15648      |
# |    total_timesteps      | 3164800    |
# | train/                  |            |
# |    approx_kl            | 0.06709627 |
# |    clip_fraction        | 0.491      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.4      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0203    |
# |    n_updates            | 19880      |
# |    policy_gradient_loss | -0.0251    |
# |    std                  | 0.431      |
# |    value_loss           | 0.00609    |
# ----------------------------------------
# Forces on test set: 633.832500
# -----------------------------------------
# | forces                  | 767.9723    |
# | rew_unnormalized        | -3087.5305  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 0.99575156  |
# | test set forces         | 634         |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 990         |
# |    time_elapsed         | 15661       |
# |    total_timesteps      | 3168000     |
# | train/                  |             |
# |    approx_kl            | 0.079466246 |
# |    clip_fraction        | 0.541       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.4       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.023      |
# |    n_updates            | 19890       |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.431       |
# |    value_loss           | 0.0217      |
# -----------------------------------------
# Forces on test set: 634.010859
# -----------------------------------------
# | forces                  | 725.049     |
# | rew_unnormalized        | -2526.0063  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.0520835   |
# | test set forces         | 634         |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 991         |
# |    time_elapsed         | 15675       |
# |    total_timesteps      | 3171200     |
# | train/                  |             |
# |    approx_kl            | 0.076075196 |
# |    clip_fraction        | 0.513       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.4       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0486     |
# |    n_updates            | 19900       |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.43        |
# |    value_loss           | 0.00728     |
# -----------------------------------------
# Forces on test set: 631.273242
# ----------------------------------------
# | forces                  | 755.7283   |
# | rew_unnormalized        | -3065.9697 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 0.9973837  |
# | test set forces         | 631        |
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 992        |
# |    time_elapsed         | 15688      |
# |    total_timesteps      | 3174400    |
# | train/                  |            |
# |    approx_kl            | 0.06671506 |
# |    clip_fraction        | 0.489      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.3      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0504    |
# |    n_updates            | 19910      |
# |    policy_gradient_loss | -0.0234    |
# |    std                  | 0.43       |
# |    value_loss           | 0.00382    |
# ----------------------------------------
# Forces on test set: 630.511797
# -----------------------------------------
# | forces                  | 757.9003    |
# | rew_unnormalized        | -2728.5928  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.0311573   |
# | test set forces         | 631         |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 993         |
# |    time_elapsed         | 15702       |
# |    total_timesteps      | 3177600     |
# | train/                  |             |
# |    approx_kl            | 0.111090794 |
# |    clip_fraction        | 0.526       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.3       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0356     |
# |    n_updates            | 19920       |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.43        |
# |    value_loss           | 0.00538     |
# -----------------------------------------
# Forces on test set: 631.794688
# ----------------------------------------
# | forces                  | 770.51117  |
# | rew_unnormalized        | -2731.8643 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.0305634  |
# | test set forces         | 632        |
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 994        |
# |    time_elapsed         | 15715      |
# |    total_timesteps      | 3180800    |
# | train/                  |            |
# |    approx_kl            | 0.09010359 |
# |    clip_fraction        | 0.508      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.3      |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0686    |
# |    n_updates            | 19930      |
# |    policy_gradient_loss | -0.0257    |
# |    std                  | 0.43       |
# |    value_loss           | 0.00328    |
# ----------------------------------------
# Forces on test set: 631.023047
# ----------------------------------------
# | forces                  | 752.00287  |
# | rew_unnormalized        | -2513.3796 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.0523504  |
# | test set forces         | 631        |
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 995        |
# |    time_elapsed         | 15728      |
# |    total_timesteps      | 3184000    |
# | train/                  |            |
# |    approx_kl            | 0.05173677 |
# |    clip_fraction        | 0.503      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.3      |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0302    |
# |    n_updates            | 19940      |
# |    policy_gradient_loss | -0.021     |
# |    std                  | 0.43       |
# |    value_loss           | 0.00365    |
# ----------------------------------------
# Forces on test set: 630.483477
# ----------------------------------------
# | forces                  | 746.8382   |
# | rew_unnormalized        | -2571.2036 |
# | rollout/                |            |
# |    ep_len_mean          | 32.0       |
# |    ep_rew_mean          | 1.0462506  |
# | test set forces         | 630        |
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 996        |
# |    time_elapsed         | 15741      |
# |    total_timesteps      | 3187200    |
# | train/                  |            |
# |    approx_kl            | 0.08456355 |
# |    clip_fraction        | 0.519      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.3      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.05      |
# |    n_updates            | 19950      |
# |    policy_gradient_loss | -0.0254    |
# |    std                  | 0.43       |
# |    value_loss           | 0.00228    |
# ----------------------------------------
# Forces on test set: 632.258477
# -----------------------------------------
# | forces                  | 712.5145    |
# | rew_unnormalized        | -2371.4075  |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.0661584   |
# | test set forces         | 632         |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 997         |
# |    time_elapsed         | 15754       |
# |    total_timesteps      | 3190400     |
# | train/                  |             |
# |    approx_kl            | 0.099510185 |
# |    clip_fraction        | 0.526       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.3       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0596     |
# |    n_updates            | 19960       |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.429       |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# Forces on test set: 632.430195
# -----------------------------------------
# | forces                  | 731.74945   |
# | rew_unnormalized        | -2727.728   |
# | rollout/                |             |
# |    ep_len_mean          | 32.0        |
# |    ep_rew_mean          | 1.0299137   |
# | test set forces         | 632         |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 998         |
# |    time_elapsed         | 15767       |
# |    total_timesteps      | 3193600     |
# | train/                  |             |
# |    approx_kl            | 0.070478335 |
# |    clip_fraction        | 0.474       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.2       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0314      |
# |    n_updates            | 19970       |
# |    policy_gradient_loss | -0.0254     |
# |    std                  | 0.429       |
# |    value_loss           | 0.00237     |
# -----------------------------------------

# %% [markdown]
# ## CFE Chain Initialization

# %% [markdown]
# To classify the results of the reinforcement learning method, they are compared to a supervised control force estimator approach using a differentiable physics loss. This comparison seems fair as both algorithms work by optimizing through trial and error.
#
# The CFE approach has access to the gradient data provided by the differentiable solver, making it possible to trace the loss over multiple timesteps and enabling the model to better comprehend long term effects of generated forces.
#
# The reinforcement learning approach on the other hand uses a dedicated value estimator network (critic) to predict the sum of rewards generated from a certain state. These are then used to update a policy network (actor) which, analogously to the control force estimator network, predicts the forces to control the simulation. The reinforcement learning algorithm is not limited by training dataset size, as new training samples are generated on policy. However, this also introduces additional simulation overhead during training. This can increase training duration.

# %%
from control.pde.burgers import BurgersPDE
from control.control_training import ControlTraining
from control.sequences import StaggeredSequence

# %%
cfe_app = ControlTraining(
    step_count,
    BurgersPDE(domain, viscosity, dt),
    datapath=data_path,
    val_range=val_range,
    train_range=train_range,
    trace_to_channel=lambda trace: 'burgers_velocity',
    obs_loss_frames=[],
    trainable_networks=['CFE'],
    sequence_class=StaggeredSequence,
    batch_size=100,
    view_size=20,
    learning_rate=1e-3,
    learning_rate_half_life=1000,
    dt=dt
).prepare()

# %%
forces = []

for epoch in range(10000):
    cfe_app.progress()
    # Check the amount of forces the current model is producing
    if epoch % 10 == 0:
        # Divide by time delta to retrieve forces from L1 distances
        f = cfe_app.infer_scalars(test_range)['Total Force'] / dt
        forces.append(f)
        print('Forces: %f' % f)

# %%
cfe_checkpoint = cfe_app.save_model()
cfe_checkpoint

# %% [markdown]
# Run the cell below to load a trained model:

# %%
cfe_app.load_checkpoints({net: 'cfe-models/bench/checkpoint_00010000' for net in ['OP2', 'OP4', 'OP8', 'OP16', 'OP32']})

# %%
path_template = os.path.join('..', 'networks', 'cfe-models', 'bench', 'checkpoint_%08i')

for i in range(10000 // 50):
    
plt.plot(forces)
plt.show

# %% [markdown]
# ## Trajectory Comparison

# %% [markdown]
# Now we are set up to perform some face-to-face comparisons between the different methods.

# %%
rl_frames, gt_frames, pass_frames = rl_trainer.infer_test_set_frames()

cfe_frames = cfe_app.infer_all_frames(test_range)
cfe_frames = [s.burgers.velocity.data for s in cfe_frames]

# %%
index_in_set = 7
fig, axs = plt.subplots(2, 2, figsize=(12.8, 9.6))

axs[0, 0].set_title('Ground Truth')
axs[0, 1].set_title('Uncontrolled')
axs[1, 0].set_title('Reinforcement Learning')
axs[1, 1].set_title('Supervised Control Force Estimator')

for subplot_idcs in [(0,0), (0,1), (1,0), (1,1)]:
    axs[subplot_idcs].set_ylim(-2, 2)
    axs[subplot_idcs].set_xlabel('x')
    axs[subplot_idcs].set_ylabel('u(x)')
    axs[subplot_idcs].legend(['Initial state in dark red, final state in dark blue,'])
    
def plot_w_label(xy, field): 
    color = bplt.gradient_color(0, step_count+1)
    axs[xy].plot(field[0][index_in_set].squeeze(), color=color, linewidth=0.8, label='Initial state in dark red, final state in dark blue,')
    axs[xy].legend()
    
# Plot the first states and create a legend for each plot
plot_w_label((0, 0), gt_frames)
plot_w_label((0, 1), pass_frames)
plot_w_label((1, 0), rl_frames)
plot_w_label((1, 1), cfe_frames)
    
# Plot the remaining states
for frame in range(1, step_count + 1):
    color = bplt.gradient_color(frame, step_count+1)
    plot = lambda xy, field: axs[xy].plot(field[frame][index_in_set].squeeze(), color=color, linewidth=0.8)
    plot((0,0), gt_frames)
    plot((0,1), pass_frames)
    plot((1,0), rl_frames)
    plot((1,1), cfe_frames)

# %%
def infer_forces(frames):
    frames = np.array(frames)
    
    b = Burgers(diffusion_substeps=diffusion_substeps)
    to_state = lambda v: BurgersVelocity(domain, velocity=v, viscosity=viscosity) 
        
    # Simulate all timesteps of all trajectories at once
    # => concatenate all frames in batch dimension
    prv = to_state(frames[:-1].reshape((-1,) + frames.shape[2:]))
    prv_sim = b.step(prv, dt=dt)
    
    forces = (frames[1:] - prv_sim.velocity.data.reshape(step_count, -1, *frames.shape[2:])) / dt
    
    # Sanity check, should be able to reconstruct goal state with forces
    s = to_state(frames[0])
    for i in range(step_count):
        f = forces[i].reshape(s.velocity.data.shape)
        effect = FieldEffect(CenteredGrid(f, box=domain.box), ['velocity'])
        s = b.step(s, dt, (effect,))
    diff = frames[-1] - s.velocity.data
    print('Maximum deviation from target state: %f' % np.abs(diff).max())
    return forces

    
gt_forces = np.abs(infer_forces(gt_frames)).sum(axis=(0, 2)).squeeze()
cfe_forces = np.abs(infer_forces(cfe_frames)).sum(axis=(0, 2)).squeeze()
rl_forces = rl_trainer.infer_test_set_forces()

# %%
plt.figure(figsize=(12.8, 9.6))
plt.scatter(gt_forces, cfe_forces, label='CFE')
plt.scatter(gt_forces, rl_forces, label='RL')
plt.plot([x * 100 for x in range(15)], [x * 100 for x in range(15)], label='Same forces as original')
plt.xlabel('ground truth')
plt.xlim(0, 1500)
plt.ylim(0, 1500)
plt.ylabel('reconstruction')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12.8, 9.6))
plt.scatter(rl_forces, cfe_forces)
plt.xlabel('reinforcement learning')
plt.ylabel('control force estimator')
plt.plot([x * 100 for x in range(15)], [x * 100 for x in range(15)], label='Same forces cfe rl')
plt.xlim(0, 1500)
plt.ylim(0, 1500)
plt.grid()
plt.legend()
plt.show()

# %%
w=0.25
plot_count=20
plt.figure(figsize=(12.8, 9.6))
plt.bar([i - w for i in range(plot_count)], rl_forces[:plot_count], width=w, align='center', label='RL')
plt.bar([i + w for i in range(plot_count)], cfe_forces[:plot_count], width=w, align='center', label='CFE')
plt.bar([i for i in range(plot_count)], gt_forces[:plot_count], width=w, align='center', label='GT')
plt.xlabel('Scenes')
plt.xticks(range(plot_count))
plt.ylabel('Forces')
plt.legend()
plt.show()
